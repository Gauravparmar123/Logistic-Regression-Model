# %% [markdown]
#                                                                  import Library

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\gaurav\Downloads\logistic_regression.csv")

# %%
data
# Out:
#      Studied     Slept  Passed
# 0   4.855064  9.639962       1
# 1   8.625440  0.058927       0
# 2   3.828192  0.723199       0
# 3   7.150955  3.899420       1
# 4   6.477900  8.198181       1
# ..       ...       ...     ...
# 95  0.022280  2.658428       0
# 96  7.630637  7.405351       1
# 97  3.684997  5.049965       0
# 98  7.484260  6.059396       1
# 99  2.030708  3.937267       0
#
# [100 rows x 3 columns]

# %% [markdown]
#                                                                Data Visulaization

# %%
# import the required libraries 

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x="Studied",y="Slept",data=data,hue="Passed")
# Out:
# <Axes: xlabel='Studied', ylabel='Slept'>

# %%
# Now taking Independent and Dependant variable's
x=data[["Studied","Slept"]]
y=data[["Passed"]]

# %%
# Training  & Testing of Data ,import Tarin test & split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
# Apply Logistic Regression 
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
# Now fit our training data into our model
model.fit(x_train,y_train)
# Out:
# C:\Users\gaurav\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
# Check Score of Prediction
model.score(x_test,y_test)
# Out:
# 0.8666666666666667

# %%
# Prediction on future data or new data
import numpy as np
newdata=(4.87,3.3)
newdata_array=np.array(newdata)

# %%
# Now converting new data to 2d array
in_newdata=newdata_array.reshape(1,-1)

# %%
in_newdata
# Out:
# array([[4.87, 3.3 ]])

# %%
# Predict result
predict1=model.predict(in_newdata)
# Out:
# C:\Users\gaurav\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
predict1
# Out:
# array([0], dtype=int64)
